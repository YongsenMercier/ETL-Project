# %%
#import dependencies
import pandas as pd
import requests
import json

# %%
pokemon = "pokemon.csv"
pokemon_df = pd.read_csv(pokemon, encoding="ISO-8859-1")

# %%
pokemon_df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
column_list = [20,21,22,23,24,29,36,37,31]
pokemon_df=pokemon_df.drop(columns=pokemon_df.columns[column_list])
#pokemon_df.drop(columns=['base_egg_steps', 'base_happiness', 'base_total', ])

# %%
pokemon_df2 = pokemon_df.set_index(["pokedex_number"])
pokemon_df2
# Out:
#                                   abilities  against_bug  against_dark  \
# pokedex_number
# 1               ['Overgrow', 'Chlorophyll']         1.00           1.0
# 2               ['Overgrow', 'Chlorophyll']         1.00           1.0
# 3               ['Overgrow', 'Chlorophyll']         1.00           1.0
# 4                  ['Blaze', 'Solar Power']         0.50           1.0
# 5                  ['Blaze', 'Solar Power']         0.50           1.0
# ...                                     ...          ...           ...
# 797                         ['Beast Boost']         0.25           1.0
# 798                         ['Beast Boost']         1.00           1.0
# 799                         ['Beast Boost']         2.00           0.5
# 800                         ['Prism Armor']         2.00           2.0
# 801                          ['Soul-Heart']         0.25           0.5
#
#                 against_dragon  against_electric  against_fairy  \
# pokedex_number
# ...

# %%
pokemon_df2 = pokemon_df2.iloc[0:386, :]
pokemon_df2
# Out:
#                                   abilities  against_bug  against_dark  \
# pokedex_number
# 1               ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2               ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3               ['Overgrow', 'Chlorophyll']          1.0           1.0
# 4                  ['Blaze', 'Solar Power']          0.5           1.0
# 5                  ['Blaze', 'Solar Power']          0.5           1.0
# ...                                     ...          ...           ...
# 382                             ['Drizzle']          1.0           1.0
# 383                             ['Drought']          1.0           1.0
# 384                            ['Air Lock']          0.5           1.0
# 385                        ['Serene Grace']          1.0           2.0
# 386                            ['Pressure']          2.0           2.0
#
#                 against_dragon  against_electric  against_fairy  \
# pokedex_number
# ...

# %%
pokemon_df3 = pokemon_df2[["name", "generation", "hp", "experience_growth", "abilities", "against_bug", "against_dark", "against_dragon", "against_electric",
                          "against_fairy", "against_fight", "against_fire", "against_flying", "against_ghost", "against_grass", "against_ground",
                           "against_ice", "against_normal", "against_poison", "against_psychic", "against_rock", "against_steel", "against_water", "attack",
                          "defense","height_m","sp_attack","sp_defense","speed","weight_kg","is_legendary"]]
pokemon_df3
# Out:
#                          name  generation   hp  experience_growth  \
# pokedex_number
# 1                   Bulbasaur           1   45            1059860
# 2                     Ivysaur           1   60            1059860
# 3                    Venusaur           1   80            1059860
# 4                  Charmander           1   39            1059860
# 5                  Charmeleon           1   58            1059860
# ...                       ...         ...  ...                ...
# 382                    Kyogre           3  100            1250000
# 383                   Groudon           3  100            1250000
# 384                  Rayquaza           3  105            1250000
# 385                   Jirachi           3  100            1250000
# 386             Deoxys-normal           3   50            1250000
#
#                                   abilities  against_bug  against_dark  \
# pokedex_number
# ...

# %%
poke_name = pokemon_df3["name"]

# %%
poke_name

# %%
type_list1 = []
type_list2 = []

base = "https://pokeapi.co/api/v2/pokemon/"
try:
    for poke in poke_name:
        url = base + poke.lower() + "/"
        data = requests.get(url).json()
        type_list1.append(data["types"][0]["type"]['name'])
        print(f"{poke}")
        try:
            type_list2.append(data["types"][1]["type"]['name'])
        except:
            type_list2.append("N/A")
except:
    print("Something went wrong.")
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# Charmander
# Charmeleon
# Charizard
# Squirtle
# Wartortle
# Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran-F
# Nidorina
# Nidoqueen
# Nidoran-M
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# Ponyta
# Rapidash
# Slowpoke
# Slowbro
# Magnemite
# Magneton
# Farfetchd
# Doduo
# Dodrio
# Seel
# Dewgong
# Grimer
# Muk
# Shellder
# Cloyster
# Gastly
# Haunter
# Gengar
# Onix
# ...

# %%
type_list2
# Out:
# ['poison',
#  'poison',
#  'poison',
#  'N/A',
#  'N/A',
#  'flying',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'flying',
#  'poison',
#  'poison',
#  'poison',
#  'flying',
#  'flying',
#  'flying',
#  'N/A',
#  'N/A',
#  'flying',
#  'flying',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'ground',
#  'N/A',
#  'N/A',
#  'ground',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'fairy',
#  'fairy',
#  'flying',
#  'flying',
#  'poison',
#  'poison',
#  'poison',
#  'grass',
#  'grass',
#  'poison',
#  'poison',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'fighting',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'poison',
#  'poison',
#  'poison',
#  'poison',
#  'poison',
#  'ground',
#  'ground',
#  'ground',
#  'N/A',
#  'N/A',
#  'psychic',
#  'psychic',
#  'steel',
#  'steel',
#  'flying',
#  'flying',
#  'flying',
#  'N/A',
#  'ice',
# ...
